# %% [markdown]
# # Read Source table

# %%
# %sql
SELECT * FROM workspace.bronze.erp_px_cat_g1v2 LIMIT 5

# %% [markdown]
# # Drop the target table if already exists

# %%
# %sql
DROP TABLE IF EXISTS workspace.silver.erp_px_cat_g1v2

# %% [markdown]
# # Create the target table

# %%
# %sql
CREATE OR REPLACE TABLE workspace.silver.erp_px_cat_g1v2 
(category_id STRING, category STRING, subcategory STRING, maintenance STRING) USING DELTA

# %% [markdown]
# # Insert source table to the Target Table

# %%
# %sql
INSERT OVERWRITE workspace.silver.erp_px_cat_g1v2
SELECT * FROM workspace.bronze.erp_px_cat_g1v2

# %% [markdown]
# # Sanity Checks of Target Table

# %%
# %sql
SELECT COUNT(*) FROM workspace.silver.erp_px_cat_g1v2

# %% [markdown]
# # View the Target table changes

# %%
# %sql
DESCRIBE HISTORY workspace.silver.erp_px_cat_g1v2
